# %% [markdown]
# <a href="https://colab.research.google.com/github/NHymavathi/fmml.resporitories/blob/main/FMML_M8_L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-15 00:48:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   110MB/s    in 0.6s
#
# 2025-03-15 00:48:58 (110 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12921  1711.05825v2  Approximate Bayesian computation (ABC) and syn...  stat
# 23057  1802.09596v1  Modern machine learning algorithms for classif...  stat
# 34755  1801.05613v2  We consider methods for learning vector repres...    cs
# 6173   1608.08063v1  Wasserstein Discriminant Analysis (WDA) is a n...  stat
# 10503   1205.1287v7  Fetal ECG (FECG) telemonitoring is an importan...  stat
# ...             ...                                                ...   ...
# 425    1708.07689v1  Recently, deep neural networks have demonstrat...  stat
# 22472  1608.07494v3  We improve existing instability-based methods ...  stat
# 11762  1611.06585v2  We propose a black-box variational inference m...  stat
# 28078  1705.05787v1  Verifying the identity of a person using handw...    cs
# 21678   0909.4386v1  We describe a method for inferring linear caus...  stat
#
#                                                    title  year  \
# 12921                  Bootstrapped synthetic likelihood  2017
# 23057  Tunability: Importance of Hyperparameters of M...  2018
# 34755  Query2Vec: An Evaluation of NLP Techniques for...  2018
# 6173                   Wasserstein Discriminant Analysis  2016
# 10503  Compressed Sensing for Energy-Efficient Wirele...  2012
# ...                                                  ...   ...
# 425    Understanding and Comparing Deep Neural Networ...  2017
# 22472  Estimating the Number of Clusters via Normaliz...  2016
# 11762  Variational Boosting: Iteratively Refining Pos...  2016
# 28078  Learning Features for Offline Handwritten Sign...  2017
# 21678  Telling cause from effect based on high-dimens...  2009
#
#                                                 keywords
# 12921  [approximate, computation, synthetic, likeliho...
# 23057  [algorithms, classification, regression, param...
# 34755  [representations, generalized, analytics, incl...
# 6173   [wasserstein, discriminant, supervised, classi...
# 10503  [telemonitoring, important, telemedicine, tele...
# ...                                                  ...
# 425    [demonstrated, excellent, performances, recogn...
# 22472  [instability, selection, normalizing, instabil...
# 11762  [variational, inference, approximate, intracta...
# 28078  [verifying, handwritten, signatures, challengi...
# 21678  [inferring, relations, dimensional, variables,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12921    [approximate, computation, synthetic, likeliho...
# 23057    [algorithms, classification, regression, param...
# 34755    [representations, generalized, analytics, incl...
# 6173     [wasserstein, discriminant, supervised, classi...
# 10503    [telemonitoring, important, telemedicine, tele...
#                                ...
# 5390     [correlated, supervised, algorithm, regression...
# 31532    [motivated, compression, potential, improvemen...
# 21793    [empirically, stochastic, annealing, posterior...
# 881      [representations, representations, questions, ...
# 36904    [dichotomous, preferences, cooperative, coalit...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8851 words.
# Out of those 4539 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dc1f4cb3-0d1c-4b0c-8904-198b45632b45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc1f4cb3-0d1c-4b0c-8904-198b45632b45")) {                    Plotly.newPlot(                        "dc1f4cb3-0d1c-4b0c-8904-198b45632b45",                        [{"x":["techniques","expensive","inference","conditional","bootstrapping","approximate","simulations","distributions","computationally","evaluated","simulator","computation","algorithm","estimated","synthetic","estimates","simulated","infeasible","different","efficiency","algorithms","accurately","improving","parameter","likelihood","investigate","subsamples","pointwise","determines","bootstrapped","simulating","posterior","considered","importance","benchmarking","classification","optimized","frequently","interesting","parameters","specified","consuming","important","carefully","performance","statistical","hyperparameter","formalize","regression","alternative","quantifying","hyperparameters","terminology","investigated","conclusions","appropriately","predicting","surprisingly","generalized","foundation","recommended","analytics","requiring","outperform","workloads","application","specialized","classifier","execution","syntactic","unrelated","summarization","prediction","representations","selection","recommendation","engineering","evaluation","approaches","including","automatically","promising","projected","automatic","experiments","following","wasserstein","differentiation","maximizes","numerical","classical","dispersion","regularized","computing","quantities","projection","principles","interactions","underlying","iterations","distances","discriminant","transport","distribution","optimization","visualization","supervised","dimensional","efficient","characteristics","technique","independent","especially","framework","experimental","desirable","recordings","component","furthermore","multichannel","consumption","ambulatory","generally","reconstruction","compressed","compression","contamination","decomposition","reconstructed","particularly","reconstruct","prominent","computational","structural","notoriously","syntactical","introduced","propositional","parameterized","preconditions","tractable","difficulty","complexity","determine","initiated","difficult","restrictions","polynomial","schedules","developed","increased","investigating","artificial","maintaining","environments","robustness","challenge","practical","reinforcement","sequential","developing","extension","significant","approximation","benchmark","comparison","particular","applications","exploration","empirical","uncertainty","highlight","successful","converging","established","contextual","understand","exploitation","attractive","tradeoffs","information","demonstrate","introduce","selective","extraction","theoretic","extractor","smartphones","effectiveness","implement","sensitive","utilization","preserving","constraints","normalization","formulated","identifies","coordinates","foreground","agreement"],"y":[401,70,227,97,5,109,31,107,88,156,13,135,844,60,146,75,61,14,722,153,651,68,99,129,60,138,1,1,15,0,7,40,115,72,10,512,45,20,64,251,36,40,349,29,916,140,9,17,105,96,9,14,7,48,20,8,74,34,65,16,5,15,54,101,3,255,29,150,32,45,5,33,223,219,161,34,55,259,466,274,184,118,25,209,592,64,6,2,12,80,81,1,32,111,12,50,35,73,125,23,31,19,8,221,294,39,174,167,411,81,243,129,132,546,378,33,8,106,174,5,21,1,69,91,24,43,1,78,27,86,30,14,286,89,7,3,131,25,14,3,32,59,231,73,3,148,12,66,5,205,51,13,137,40,91,97,170,140,122,58,65,87,245,113,200,127,280,447,57,146,64,32,65,5,51,53,66,19,30,6,676,561,321,15,142,39,4,4,202,70,55,16,45,139,32,34,25,20,20,23],"type":"bar"},{"x":["techniques","expensive","inference","conditional","bootstrapping ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4539,), (4539, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Denoising</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>Covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>Single</span> <span style=''>Particle</span> <span style=''>Cryo</span> <span style=''>EM</span> <span style=''>Images</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>restoration</span> <span style=''>in</span> <span style=''>cryo</span> <span style=''>EM</span> <span style=''>entails</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correcting</span> <span style=''>for</span> <span style=''>the</span> <span style=''>effects</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Contrast</span> <span style=''>Transfer</span> <span style=''>Function</span> <span style=''>(CTF)</span> <span style=''>and</span> <span style=''>noise</span> <span style=''>Popular</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>restoration</span> <span style=''>include</span> <span style=''>phase</span> <span style=''>flipping</span> <span style=''>which</span> <span style=''>corrects</span> <span style=''>only</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Fourier</span> <span style=''>phases</span> <span style=''>but</span> <span style=''>not</span> <span style=''>amplitudes</span> <span style=''>and</span> <span style=''>Wiener</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>which</span> <span style=''>requires</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>signal</span> <span style=''>to</span> <span style=''>noise</span> <span style=''>ratio</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>restoration</span> <span style=''>method</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>Covariance</span> <span style=''>Wiener</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Filtering</span> <span style=''>(CWF)</span> <span style=''>In</span> <span style=''>CWF</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>covariance</span> <span style=''>matrix</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>images</span> <span style=''>is</span> <span style=''>used</span> <span style=''>within</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>Wiener</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>the</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>restoration</span> <span style='background-color:rgba(0, 255, 0, 0.4736842105263158);'>deconvolution</span> <span style=''>problem</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>covariance</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>new</span> <span style=''>and</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style=''>To</span> <span style=''>Real</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>to</span> <span style=''>real</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>where</span> <span style=''>one</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>regress</span> <span style=''>a</span> <span style=''>mapping</span> <span style=''>f</span> <span style=''>that</span> <span style=''>takes</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariate</span> <span style=''>Pin</span> <span style=''>mathcalI</span> <span style=''>(for</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>mathcalI)</span> <span style=''>and</span> <span style=''>outputs</span> <span style=''>a</span> <span style=''>real</span> <span style=''>valued</span> <span style=''>response</span> <span style=''>Yf(P)</span> <span style=''>epsilon</span> <span style=''>This</span> <span style=''>setting</span> <span style=''>was</span> <span style=''>recently</span> <span style=''>studied</span> <span style=''>and</span> <span style=''>a</span> <span style=''>Kernel</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>and</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>have</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluating</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Kernel</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>scales</span> <span style=''>as</span> <span style=''>Omega(N)</span> <span style=''>This</span> <span style=''>causes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situation</span> <span style=''>where</span> <span style=''>a</span> <span style=''>large</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>data</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style=''>for</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>risk</span> <span style=''>but</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>cost</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>becomes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>infeasible</span> <span style=''>when</span> <span style=''>the</span> <span style=''>data ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Completion</span> <span style=''>and</span> <span style=''>Related</span> <span style=''>Problems</span> <span style=''>via</span> <span style=''>Strong</span> <span style=''>Duality</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>studies</span> <span style=''>the</span> <span style=''>strong</span> <span style=''>duality</span> <span style=''>of</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>factorization</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>its</span> <span style=''>dual</span> <span style=''>have</span> <span style=''>the</span> <span style=''>same</span> <span style=''>optimum</span> <span style=''>This</span> <span style=''>has</span> <span style=''>been</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understood</span> <span style=''>for</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>but</span> <span style=''>little</span> <span style=''>was</span> <span style=''>known</span> <span style=''>for</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>factorization</span> <span style=''>program</span> <span style=''>is</span> <span style=''>the</span> <span style=''>same</span> <span style=''>as</span> <span style=''>its</span> <span style=''>bi</span> <span style=''>dual</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>program</span> <span style=''>can</span> <span style=''>be</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>solving</span> <span style=''>its</span> <span style=''>bi</span> <span style=''>dual</span> <span style=''>which</span> <span style=''>is</span> <span style=''>convex</span> <span style=''>These</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923077);'>satisfied</span> <span style=''>by</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>class</span> <span style=''>of</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>factorization</span> <span style=''>problems</span> <span style=''>although</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>factorization</span> <span style=''>problems</span> <span style=''>are</span> <span style=''>hard</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Trading</span> <span style=''>off</span> <span style=''>variance</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>is</span> <span style=''>the</span> <span style=''>method</span> <span style=''>of</span> <span style=''>choice</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>by</span> <span style=''>virtue</span> <span style=''>of</span> <span style=''>its</span> <span style=''>light</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>per</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>However</span> <span style=''>it</span> <span style=''>lags</span> <span style=''>behind</span> <span style=''>its</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>counterparts</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>due</span> <span style=''>to</span> <span style=''>high</span> <span style=''>variance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>updates</span> <span style=''>The</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Variance</span> <span style=''>Reduced</span> <span style=''>Gradient</span> <span style=''>(SVRG)</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mitigates</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>shortcoming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style=''>new</span> <span style=''>update</span> <span style=''>rule</span> <span style=''>which</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>infrequent</span> <span style=''>passes</span> <span style=''>over</span> <span style=''>the</span> <span style=''>entire</span> <span style=''>input</span> <span style=''>dataset</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>the</span> <span style=''>full</span> <span style=''>gradient</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>CheapSVRG</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>scheme</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>SVRG</span> <span style=''>but</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>the</span> <span style=''>full</span> <span style=''>gradient</span> <span style=''>it</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogate</span> <span style=''>which</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.11589050835407039)
# 	representation (0.12584429434767153)
# 	experimental (0.13437611091361537)
# 	information (0.24031283327408462)
# 	architecture (0.09207252044081052)
# 	segmentation (0.07180945609669392)
# 	different (0.2566654816921436)
# 	detection (0.13544258798435835)
# 	recognition (0.13402061855670103)
# 	convolutional (0.1293992179168148)
#
# Some Statistics words are:
# 	stochastic (0.12934071464519376)
# 	distributions (0.12934071464519376)
# 	variables (0.13990941117262204)
# 	theoretical (0.14896829391041772)
# 	statistical (0.15500754906894817)
# 	estimation (0.17513839959738298)
# 	distribution (0.18772018117765477)
# 	inference (0.1922496225465526)
# 	dimensional (0.19677906391545041)
# 	regression (0.18117765475591344)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5d02c934-093e-4ede-b0c8-2c77155bd4e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d02c934-093e-4ede-b0c8-2c77155bd4e6")) {                    Plotly.newPlot(                        "5d02c934-093e-4ede-b0c8-2c77155bd4e6",                        [{"x":["techniques","expensive","inference","conditional","bootstrapping","approximate","simulations","distributions","computationally","evaluated","simulator","computation","algorithm","estimated","synthetic","estimates","simulated","infeasible","different","efficiency","algorithms","accurately","improving","parameter","likelihood","investigate","subsamples","pointwise","determines","bootstrapped","simulating","posterior","considered","importance","benchmarking","classification","optimized","frequently","interesting","parameters","specified","consuming","important","carefully","performance","statistical","hyperparameter","formalize","regression","alternative","quantifying","hyperparameters","terminology","investigated","conclusions","appropriately","predicting","surprisingly","generalized","foundation","recommended","analytics","requiring","outperform","workloads","application","specialized","classifier","execution","syntactic","unrelated","summarization","prediction","representations","selection","recommendation","engineering","evaluation","approaches","including","automatically","promising","projected","automatic","experiments","following","wasserstein","differentiation","maximizes","numerical","classical","dispersion","regularized","computing","quantities","projection","principles","interactions","underlying","iterations","distances","discriminant","transport","distribution","optimization","visualization","supervised","dimensional","efficient","characteristics","technique","independent","especially","framework","experimental","desirable","recordings","component","furthermore","multichannel","consumption","ambulatory","generally","reconstruction","compressed","compression","contamination","decomposition","reconstructed","particularly","reconstruct","prominent","computational","structural","notoriously","syntactical","introduced","propositional","parameterized","preconditions","tractable","difficulty","complexity","determine","initiated","difficult","restrictions","polynomial","schedules","developed","increased","investigating","artificial","maintaining","environments","robustness","challenge","practical","reinforcement","sequential","developing","extension","significant","approximation","benchmark","comparison","particular","applications","exploration","empirical","uncertainty","highlight","successful","converging","established","contextual","understand","exploitation","attractive","tradeoffs","information","demonstrate","introduce","selective","extraction","theoretic","extractor","smartphones","effectiveness","implement","sensitive","utilization","preserving","constraints","normalization","formulated","identifies","coordinates","foreground","agreement","representation","hierarchically","neighbors","resonance","adaptation","parameterization","separates","connected","segmenting","annotations","intrinsic","segmentation","availability","favorably","background","imbalance","convolutional","architecture","linearities","eigenfunctions","probabilistic","stochastic","structures","potential","overlapping","communities","structure","predictive","relations","interpretable","memberships","interaction","international","discovers","community","knowledge","applicability","properties","irregular","conducted","histogram","rotationally","combining","invariance","invariant","depiction","chromatic","rotational","capability","extensive","alignment","sequences","sequentially","continuous","com ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	bootstrapped
# 	martingale
# 	nontrivially
# 	inversions
# 	concordant
# 	factorizes
# 	prognostics
# 	regressionclassification
# 	smoothers
# 	multistep
# 	predetermined
# 	preconditioned
# 	unavoidably
# 	extraneous
# 	recombine
# 	regularised
# 	negativity
# 	trilinear
# 	particulars
# 	underestimated
# Some words which never appear in Statistics papers:
# 	syntactic
# 	syntactical
# 	propositional
# 	initiated
# 	rotationally
# 	depiction
# 	chromatic
# 	benchmarked
# 	smartphone
# 	epistemological
# 	homomorphic
# 	formalisms
# 	stochasticnet
# 	formation
# 	neocortical
# 	conservation
# 	mammograms
# 	subroutine
# 	articulated
# 	monocular

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.061005846521167e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7433333333333333
